# %% [markdown]
# <a href="https://colab.research.google.com/github/pysr1/forecasting_2/blob/master/forecasting2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

df = pd.read_csv('https://raw.githubusercontent.com/pysr1/forecasting_2/master/seatleBike.csv')
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#                        Date                                   key   value
# 0 2012-09-30 00:00:00+00:00  Fremont Bridge East Sidewalk_Fremont  6106.0
# 1 2012-09-30 00:00:00+00:00  Fremont Bridge West Sidewalk_Fremont  6044.0
# 2 2012-10-07 00:00:00+00:00  Fremont Bridge East Sidewalk_Fremont  9443.0
# 3 2012-10-07 00:00:00+00:00  Fremont Bridge West Sidewalk_Fremont  8796.0
# 4 2012-10-14 00:00:00+00:00  Fremont Bridge East Sidewalk_Fremont  7833.0

# %%
selected = df[df['key'] == 'Fremont Bridge East Sidewalk_Fremont']
selected.set_index('Date')['value'].plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/arrays/datetimes.py:1269: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,

# %%
names = []
vol = []

for i in df['key'].unique():
  names.append(i)
  vol.append(df[df['key']== i]['value'].pct_change().dropna().std())

per_df = pd.DataFrame({'Columns': names, 'Volatility': vol})

# %%
df[df['key'] == 'West_Spokane']['value'].plot()

# %%
perc_ch
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['key'].value_counts()
# Out:
# Fremont Bridge West Sidewalk_Fremont                       383
# Fremont Bridge East Sidewalk_Fremont                       383
# Ped West_MTS                                               320
# Bike East_MTS                                              320
# MTS Trl West of I-90 Bridge Total_MTS                      320
# Bike West_MTS                                              320
# Ped East_MTS                                               320
# Ped South_Burke                                            318
# Ped North_Elliott                                          318
# East_Spokane                                               318
# BGT North of NE 70th Total_Burke                           318
# Spokane St. Bridge Total_Spokane                           318
# Elliott Bay Trail in Myrtle Edwards Park Total_Elliott     318
# Bike North_Elliott                                         318
# Ped South_Elliott                                          318
# ...
